# %% [markdown]
# # Data Explorations and Checks

# %% [markdown]
# This notebook performs foundational data validation and missing value checks on our 1950-2025 F1 final dataset.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../final_datasets/f1_unified_dataset_1950_2025.csv')
df.head()

# %% [markdown]
# ## Missing Values Check

# %%
df.isna().sum()

# %% [markdown]
# ## Data Types and Ranges

# %%
df.describe()

# %% [markdown]
# ## Circuit Types mapping validation

# %%
df['Circuit Type'].value_counts(dropna=False)
